# %% [markdown]
# <a href="https://colab.research.google.com/github/Charlene958/Data-110/blob/main/Week3_Assignment_Charlene_fall25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3: Line & Scatter Plots — Combined Notebook
#
#
#
# **What’s inside**
# - Part 1: Line Plots (original notebook, unchanged)
# - Part 2: Scatter Plots (original notebook, unchanged)
# - Part 3: Assignment (original text appended; no edits to content)

# %% [markdown]
# ## Learning Objectives (quick guide)
# - Practice mapping data to aesthetics (position, color, size, shape).
# - Create and refine **line plots** and **scatter plots** in Python/Matplotlib.
# - Apply good figure habits: titles, labels, legends, scales, and notes.
# - Complete the Week 3 assignment at the end of this notebook.

# %% [markdown]
# ## Table of Contents
# - [Part 1: Line Plots](#part-1-line-plots)
# - [Part 2: Scatter Plots](#part-2-scatter-plots)
# - [Part 3: Assignment](#part-3-assignment)
# - [Reference: Mathematical Functions](#Mathematical-Functions)

# %% [markdown]
# ## Environment Setup
# The cell below ensures NumPy and Matplotlib are imported and configures a few readability defaults. You can rerun it anytime.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Line Plots <a id='part-1-line-plots'></a>

# %% [markdown]
# **Goal.** Practice fundamentals of line plots: mapping variables to axes, labeling, and reading trends.
#
# **Tip.** Aim for: a clear title, labeled axes with units, and readable ticks. Include a legend when plotting more than one line.

# %% [markdown]
# <a href="https://colab.research.google.com/github/Reben80/Data110-22016/blob/main/Week3_line_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Line Plots

# %% [markdown]
# Perhaps the simplest of all plots is the visualization of a single function $y = f(x)$.
# Here we will take a first look at creating a simple plot of this type.
# As in all the following chapters, we'll start by setting up the notebook for plotting and  importing the packages we will use:

# %% [markdown]
# To plot a mathematical function, we first need to generate a set of
# $x$
# $x$-values. The command `np.linspace(0, 10, 1000)` creates 1000 evenly spaced points between 0 and 10, which we use as inputs. We then apply the sine function to these values and plot the result using Matplotlib:

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x))

# %% [markdown]
# If we want to create a single figure with multiple lines (see the following figure), we can simply call the `plot` function multiple times:

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# That's all there is to plotting simple functions in Matplotlib!
# We'll now dive into some more details about how to control the appearance of the axes and lines.

# %% [markdown]
# ## Adjusting the Plot: Line Colors and Styles

# %% [markdown]
# The first adjustment you might wish to make to a plot is to control the line colors and styles.
# The `plt.plot` function takes additional arguments that can be used to specify these.
# To adjust the color, you can use the `color` keyword, which accepts a string argument representing virtually any imaginable color.
# The color can be specified in a variety of ways; see the following figure for the output of the following examples:

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # hex code (RRGGBB, 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # HTML color names supported

# %% [markdown]
# If no color is specified, Matplotlib will automatically cycle through a set of default colors for multiple lines.
#
# Similarly, the line style can be adjusted using the `linestyle` keyword (see the following figure):

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# Though it may be less clear to someone reading your code, you can save some keystrokes by combining these `linestyle` and `color` codes into a single non-keyword argument to the `plt.plot` function; the following figure shows the result:

# %%
plt.plot(x, x + 0, '-g')   # solid green
plt.plot(x, x + 1, '--c')  # dashed cyan
plt.plot(x, x + 2, '-.k')  # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# These single-character color codes reflect the standard abbreviations in the RGB (Red/Green/Blue) and CMYK (Cyan/Magenta/Yellow/blacK) color systems, commonly used for digital color graphics.
#
# There are many other keyword arguments that can be used to fine-tune the appearance of the plot; for details, read through the docstring of the `plt.plot` function using IPython's help tools (see [Help and Documentation in IPython](01.01-Help-And-Documentation.ipynb)).

# %% [markdown]
# ## Adjusting the Plot: Axes Limits
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control.
# The most basic way to adjust the limits is to use the `plt.xlim` and `plt.ylim` functions (see the following figure):

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %% [markdown]
# If for some reason you'd like either axis to be displayed in reverse, you can simply reverse the order of the arguments (see the following figure):

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is `plt.axis` (note here the potential confusion between *axes* with an *e*, and *axis* with an *i*), which allows more qualitative specifications of axis limits. For example, you can automatically tighten the bounds around the current content, as shown in the following figure:

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %% [markdown]
# Or you can specify that you want an equal axis ratio, such that one unit in `x` is visually equivalent to one unit in `y`, as seen in the following figure:

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# Other axis options include `'on'`, `'off'`, `'square'`, `'image'`, and more. For more information on these, refer to the `plt.axis` docstring.

# %% [markdown]
# ## Labeling Plots
#
# As the last piece of this chapter, we'll briefly look at the labeling of plots: titles, axis labels, and simple legends.
# Titles and axis labels are the simplest such labels—there are methods that can be used to quickly set them (see the following figure):

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# The position, size, and style of these labels can be adjusted using optional arguments to the functions, described in the docstrings.

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type.
# Again, Matplotlib has a built-in way of quickly creating such a legend; it is done via the (you guessed it) `plt.legend` method.
# Though there are several valid ways of using this, I find it easiest to specify the label of each line using the `label` keyword of the `plot` function (see the following figure):

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# As you can see, the `plt.legend` function keeps track of the line style and color, and matches these with the correct label.

# %% [markdown]
# <a href="https://colab.research.google.com/github/Reben80/Data110-22016/blob/main/Week3_Scatter_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Checkpoint: Can you…
# - Explain the difference between `x` as domain vs. as an index?
# - Add axis labels and a legend to an existing line plot?
# - Adjust limits (e.g., `plt.xlim`, `plt.ylim`) to focus on a region of interest?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Practice: Modify an existing line plot or create a new one.
# Example scaffold (feel free to delete and use your data):
x = np.linspace(0, 10, 200)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label='sin(x)')
plt.plot(x, y2, label='cos(x)')
plt.title('Practice Line Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ## Part 2: Scatter Plots <a id='part-2-scatter-plots'></a>

# %% [markdown]
# ### Choosing a Plot Style
#
# Matplotlib lets you quickly change the overall look of your plots using **styles**.
# Styles control things like background color, grid lines, fonts, and line colors.
#
# To see which styles are available in your environment, run:

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# This will print a list of style names (for example: `'ggplot'`, `'fivethirtyeight'`, `'seaborn-v0_8-whitegrid'`).
# To activate one of them, use `plt.style.use("<style-name>")` with the exact name from the list:

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# Next, we  build and interpret scatter plots. Consider overplotting, scales, and encoding by color/size/shape.
#
# **Tip.** When points overlap, try transparency (`alpha`), smaller markers, or jitter. Label axes clearly and avoid chartjunk.

# %% [markdown]
# # Simple Scatter Plots

# %% [markdown]
# Another commonly used plot type is the simple scatter plot, a close cousin of the line plot.
# Instead of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.
# We’ll start by setting up the notebook for plotting and importing the packages we will use:

# %% [markdown]
# ## Scatter Plots with plt.plot
#
# In the previous chapter we looked at using `plt.plot`/`ax.plot` to produce line plots.
# It turns out that this same function can produce scatter plots as well (see the following figure):

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %% [markdown]
# The third argument in the function call is a character that represents the type of symbol used for the plotting. Just as you can specify options such as `'-'` or `'--'` to control the line style, the marker style has its own set of short string codes. The full list of available symbols can be seen in the documentation of `plt.plot`, or in Matplotlib's [online documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.markers.MarkerStyle.html). Most of the possibilities are fairly intuitive, and a number of the more common ones are demonstrated here (see the following figure):

# %% [markdown]
# For even more possibilities, these character codes can be used together with line and color codes to plot points along with a line connecting them (see the following figure):

# %%
plt.plot(x, y, '-ok');

# %% [markdown]
# Additional keyword arguments to `plt.plot` specify a wide range of properties of the lines and markers, as you can see in the following figure:

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# These kinds of options make `plt.plot` the primary workhorse for two-dimensional plots in Matplotlib.
# For a full description of the options available, refer to the [`plt.plot` documentation](https://matplotlib.org/3.5.0/api/_as_gen/matplotlib.pyplot.plot.html).

# %% [markdown]
# ## Scatter Plots with plt.scatter
#
# A second, more powerful method of creating scatter plots is the `plt.scatter` function, which can be used very similarly to the `plt.plot` function (see the following figure):

# %%
plt.scatter(x, y, marker='o');

# %% [markdown]
# The primary difference of `plt.scatter` from `plt.plot` is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.
#
# Let's show this by creating a random scatter plot with points of many colors and sizes.
# In order to better see the overlapping results, we'll also use the `alpha` keyword to adjust the transparency level (see the following figure):

# %% [markdown]
# ## plot Versus scatter: A Note on Efficiency
#
# Aside from the different features available in `plt.plot` and `plt.scatter`, why might you choose to use one over the other? While it doesn't matter as much for small amounts of data, as datasets get larger than a few thousand points, `plt.plot` can be noticeably more efficient than `plt.scatter`.
# The reason is that `plt.scatter` has the capability to render a different size and/or color for each point, so the renderer must do the extra work of constructing each point individually.
# With `plt.plot`, on the other hand, the markers for each point are guaranteed to be identical, so the work of determining the appearance of the points is done only once for the entire set of data.
# For large datasets, this difference can lead to vastly different performance, and for this reason, `plt.plot` should be preferred over `plt.scatter` for large datasets.

# %% [markdown]
# ### Checkpoint: Can you…
# - Distinguish correlation from causation in a scatter plot?
# - Add transparency (`alpha=...`) to reduce overplotting?
# - Map a third variable to marker size or a fourth to marker shape?

# %%
# Practice: Build a scatter plot with at least two encodings (e.g., color and size).
# Example scaffold (replace with your data):
rng = np.random.default_rng(0)
n = 200
x = rng.normal(0, 1, n)
y = 0.7*x + rng.normal(0, 0.7, n)
size = 40 + 60*(rng.random(n))

plt.scatter(x, y, s=size, alpha=0.7)
plt.title('Practice Scatter Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ---
# ### Before you begin the assignment
# 1. Reread the learning objectives.
# 2. Skim your Part 1/2 code to ensure it runs cleanly (restart & run all if needed).
# 3. Review your plots for titles, labels, legends, and appropriate scales.

# %% [markdown]
# ---
# ## Part 3: Assignment
#
# The following assignment consolidates the material you explored in Part 1 (Line Plots) and Part 2 (Scatter Plots). Each task has its own space for code.

# %% [markdown]
# ### 1. Setup and Styles
#
# - Import the necessary libraries (Matplotlib and NumPy)
# - Use the following code to print out all available styles:
# ```python
# import matplotlib.pyplot as plt
# print(plt.style.available)
# ```
# - Set the default style to 'seaborn-whitegrid'
# - Choose one additional style from the available list to use later in the assignment

# %%
# Your code needs to be here
import matplotlib.pyplot as plt
import numpy as np

print(plt.style.available)

plt.style.use('seaborn-v0_8-whitegrid')

additional_style = 'ggplot'
print("Default style set to 'seaborn-v0_8-whitegrid'. Additional style chosen:", additional_style)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
# Default style set to 'seaborn-v0_8-whitegrid'. Additional style chosen: ggplot

# %% [markdown]
# ### 2. Basic Line Plot
#
# - Create a plot of the quadratic function $f(x) = x^2 - 2x + 1$ over the range $[-2, 4]$
# - Use `plt.plot()` to create the plot

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-2, 4, 400)
y = x**2 - 2*x + 1
plt.plot(x, y, label=r'$f(x)=x^2-2x+1$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Quadratic: f(x) = x^2 - 2x + 1')
plt.legend()
plt.show()

# %% [markdown]
# ### 3. Multiple Lines
#
# - Create a plot with the following three functions on the same graph:
#   - $f(x) = x^3$
#   - $g(x) = e^x$
#   - $h(x) = \log(x)$ (for $x > 0$)
# - Use different colors for each line
# - Add a legend to distinguish between the functions

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 400)        # for x^3 and e^x
x_pos = np.linspace(0.1, 3, 400)   # for log(x), avoid 0

f = x**3
g = np.exp(x)
h = np.log(x_pos)

plt.plot(x, f, color='tab:blue', label=r'$f(x)=x^3$')
plt.plot(x, g, color='tab:orange', label=r'$g(x)=e^x$')
plt.plot(x_pos, h, color='tab:green', label=r'$h(x)=\log(x)$')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Multiple functions: $x^3$, $e^x$, $\log(x)$')
plt.legend()

plt.xlim(-3, 3)
plt.ylim(-30, 30)

plt.grid(True)
plt.show()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\l'
# <>:18: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipython-input-2116926205.py:18: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('Multiple functions: $x^3$, $e^x$, $\log(x)$')

# %% [markdown]
# ### 4. Styling Lines
#
# - Create a plot with the following functions, each with a different color and line style:
#   - $f(x) = x^2$
#   - $g(x) = x^3$
#   - $h(x) = x^4$
#   - $i(x) = x^5$
# - Demonstrate at least 4 different color specification methods

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1.5, 1.5, 400)
f = x**2
g = x**3
h = x**4
i = x**5
plt.figure(figsize=(8, 6))
plt.plot(x, f, color='red', linestyle='-', linewidth=2, label=r'$f(x)=x^2$')
plt.plot(x, g, 'b--', linewidth=2, label=r'$g(x)=x^3$')
plt.plot(x, h, color='#2ca02c', linestyle=':', linewidth=2, label=r'$h(x)=x^4$')
plt.plot(x, i, color=(0.6, 0.2, 0.8), linestyle='-.', linewidth=2, label=r'$i(x)=x^5$')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomials with different color specifications and line styles')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 5. Axes Limits and Scaling
#
# - Plot the function $f(x) = \frac{1}{x^2 + 1}$ over the range $[-10, 10]$
# - Set appropriate custom x and y limits to showcase the function's behavior
# - Create another plot of the same function with reversed x and y axes
# - Demonstrate the use of `plt.axis('tight')` and `plt.axis('equal')`

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 2000)
f = 1 / (x**2 + 1)
plt.figure(figsize=(6,4))
plt.plot(x, f, color='tab:blue', label=r'$f(x)=\frac{1}{x^2+1}$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('f(x) = 1 / (x^2 + 1) — Full domain')
plt.xlim(-5, 5)
plt.ylim(0, 1.1)
plt.legend()
plt.grid(True)
plt.show()
plt.figure(figsize=(6,4))
plt.plot(x, f, color='tab:orange')
plt.xlabel('x (reversed)')
plt.ylabel('f(x) (reversed)')
plt.title('Reversed axes')
ax = plt.gca()
ax.invert_xaxis()
ax.invert_yaxis()
plt.xlim(5, -5)
plt.ylim(1.1, 0)
plt.grid(True)
plt.show()
plt.figure(figsize=(6,4))
plt.plot(x, f, color='tab:green')
plt.title("plt.axis('tight')")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axis('tight')
plt.grid(True)
plt.show()
plt.figure(figsize=(6,6))
plt.plot(x, f, color='tab:purple')
plt.title("plt.axis('equal')")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axis('equal')
plt.xlim(-5, 5)
plt.ylim(-0.2, 1.2)
plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ### 6. Labels and Legends
#
# - Create a plot of $f(x) = \sqrt{x}$ and $g(x) = x^{\frac{1}{3}}$ for $x \geq 0$
# - Add a proper title, x-label, y-label, and legend
# - Try changing the legend location using `plt.legend(loc='upper left')`, etc.

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 8, 400)
f = np.sqrt(x)
g = np.cbrt(x)
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
ax = axes[0]
ax.plot(x, f, label=r'$f(x)=\sqrt{x}$', color='tab:blue', linewidth=2)
ax.plot(x, g, label=r'$g(x)=x^{1/3}$', color='tab:orange', linewidth=2)
ax.set_title('Legend: upper left')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(loc='upper left')
ax.grid(True)
ax = axes[1]
ax.plot(x, f, label=r'$f(x)=\sqrt{x}$', color='tab:blue', linewidth=2)
ax.plot(x, g, label=r'$g(x)=x^{1/3}$', color='tab:orange', linewidth=2)
ax.set_title('Legend: lower right')
ax.set_xlabel('x')
ax.legend(loc='lower right')
ax.grid(True)

fig.suptitle('Comparison of $f(x)=\sqrt{x}$ and $g(x)=x^{1/3}$ for $x\geq0$', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2061895711.py:25: SyntaxWarning: invalid escape sequence '\s'
#   fig.suptitle('Comparison of $f(x)=\sqrt{x}$ and $g(x)=x^{1/3}$ for $x\geq0$', fontsize=14)

# %% [markdown]
# ### 7. Basic Scatter Plot
#
# - Generate 50 random points using `np.random.rand()` for both x and y
# - Create a scatter plot of these points using `plt.plot()` with the 'o' marker
# - Create the same scatter plot using `plt.scatter()`

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
x = np.random.rand(50)
y = np.random.rand(50)
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].plot(x, y, 'o', markeredgecolor='k', markersize=6, label="plt.plot('o')")
axes[0].set_title("Scatter via plt.plot()")
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")
axes[0].legend()
axes[0].grid(True)
axes[1].scatter(x, y, c='C1', s=60, alpha=0.8, edgecolor='k', label='plt.scatter()')
axes[1].set_title("Scatter via plt.scatter()")
axes[1].set_xlabel("x")
axes[1].legend()
axes[1].grid(True)
plt.suptitle("50 Random Points: plt.plot('o') vs plt.scatter()")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ### 8. Customizing Scatter Plots
#
# - Generate data for the function $f(x) = x \sin(x)$ over the range $[0, 4\pi]$
# - Create a scatter plot of this data with a line connecting the points
# - Customize the plot by changing the marker size, line width, marker face color, marker edge color, and marker edge width

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 4 * np.pi, 300)
y = x * np.sin(x)

plt.figure(figsize=(8, 5))

plt.plot(x, y, color='tab:blue', linewidth=1.8, label=r'Line: $x\sin x$')

plt.scatter(
    x, y,
    s=60,
    c='lightcoral',
    edgecolors='black',
    linewidths=0.9,
    alpha=0.95,
    label='Points'
)

plt.xlabel('x')
plt.ylabel(r'$f(x)=x\sin x$')
plt.title(r'Scatter of $f(x)=x\sin x$ on $[0,4\pi]$ with connecting line')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 9. Combined Plot
#
# - Plot the function $f(x) = x \cos(x)$ over the range $[-2\pi, 2\pi]$
# - Add scatter points for x values at every $\frac{\pi}{4}$ interval
# - Use different colors and styles for the line and scatter components

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-2 * np.pi, 2 * np.pi, 800)
y = x * np.cos(x)
x_scatter = np.arange(-2 * np.pi, 2 * np.pi + 1e-10, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

plt.figure(figsize=(8, 5))
plt.plot(x, y, color='tab:blue', linestyle='-', linewidth=2, label=r'Line: $f(x)=x\cos x$')
plt.scatter(
    x_scatter, y_scatter,
    s=100,
    c='crimson',
    edgecolor='k',
    linewidths=1.0,
    marker='o',
    zorder=5,
    label=r'Scatter: $x=k\pi/4$'
)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title(r'Combined plot of $f(x)=x\cos x$ with scatter at $x=k\pi/4$')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. Custom Plot with Alternative Style
#
# - Choose two or more functions from the following list:
#   - $h(x) = \frac{\sin(x)}{x}$  (with appropriate handling for $x=0$)
#   - $i(x) = \arctan(x)$
#   - $j(x) = \frac{1}{1 + e^{-x}}$  (logistic function)
# - Create a custom plot that combines at least 4 concepts learned (e.g., multiple functions, scatter points, custom colors, line styles, limits, labels, and legend)
# - Use the alternative style you chose in Task 1 for this plot
# - Add comments explaining your choices, the significance of the functions you chose, and how the alternative style affects the plot's appearance

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
x = np.linspace(-10, 10, 2000)
h = np.where(x == 0.0, 1.0, np.sin(x) / x)
i = np.arctan(x)
j = 1.0 / (1.0 + np.exp(-x))
x_scatter = np.array([-9.0, -6.0, -3.0, -1.5, 0.0, 1.5, 3.0, 6.0, 9.0])
h_sc = np.where(x_scatter == 0.0, 1.0, np.sin(x_scatter) / x_scatter)
i_sc = np.arctan(x_scatter)
j_sc = 1.0 / (1.0 + np.exp(-x_scatter))

plt.figure(figsize=(10, 6))
plt.plot(x, h, linestyle='--', color='teal', linewidth=2, label=r'$h(x)=\frac{\sin x}{x}$')
plt.plot(x, i, linestyle='-', color='m', linewidth=2, label=r'$i(x)=\arctan(x)$')
plt.plot(x, j, linestyle=':', color='#1f77b4', linewidth=2, label=r'$j(x)=\frac{1}{1+e^{-x}}$')
plt.scatter(x_scatter, h_sc, s=70, c='lightgreen', edgecolors='k', linewidths=0.8,
            marker='o', zorder=5, label='h(x) samples (sine/x)')
plt.scatter(x_scatter, i_sc, s=70, c=(0.9, 0.6, 0.0), edgecolors='k', linewidths=0.8,
            marker='s', zorder=5, label='i(x) samples (arctan)')
plt.scatter(x_scatter, j_sc, s=70, c='violet', edgecolors='k', linewidths=0.8,
            marker='^', zorder=5, label='j(x) samples (logistic)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Combined functions: $\\frac{\\sin x}{x}$, $\\arctan x$, and logistic $\\frac{1}{1+e^{-x}}$')
plt.xlim(-10, 10)
plt.ylim(-1.6, 1.6)
plt.legend(loc='upper right')
plt.annotate('h(0) = 1 (limit)', xy=(0, 1.0), xytext=(1.2, 1.25),
             arrowprops=dict(arrowstyle='->', lw=1.2), fontsize=10, bbox=dict(boxstyle='round', fc='w'))

plt.grid(True, linestyle=':', linewidth=0.6, alpha=0.8)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-800865.py:10: RuntimeWarning: invalid value encountered in divide
#   h_sc = np.where(x_scatter == 0.0, 1.0, np.sin(x_scatter) / x_scatter)
# /tmp/ipython-input-800865.py:20: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x_scatter, i_sc, s=70, c=(0.9, 0.6, 0.0), edgecolors='k', linewidths=0.8,

# %% [markdown]
# ### 11. Style Comparison
#
# - Choose one of your previous plots (Tasks 2-9)
# - Recreate it using three different styles: the default style, and your chosen alternative style
# - Compare and contrast the appearances, discussing which style might be most appropriate for the specific data being plotted

# %%
# Your code needs to be here
import numpy as np
import matplotlib.pyplot as plt
x_line = np.linspace(-2 * np.pi, 2 * np.pi, 800)
y_line = x_line * np.cos(x_line)
x_scatter = np.arange(-2 * np.pi, 2 * np.pi + 1e-10, np.pi / 4)
y_scatter = x_scatter * np.cos(x_scatter)

styles = [
    ('Matplotlib default', 'default'),
    ("Assignment default ('seaborn-v0_8-whitegrid')", 'seaborn-v0_8-whitegrid'),
    ("Chosen alternative ('ggplot')", 'ggplot'),
]

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

for ax, (label, style_name) in zip(axes, styles):
    plt.style.use(style_name)
    ax.plot(x_line, y_line, color='tab:blue', linestyle='-', linewidth=2, label=r'$f(x)=x\cos x$')
    ax.scatter(
        x_scatter, y_scatter,
        s=90, c='crimson', edgecolor='k', linewidths=0.9, marker='o', zorder=5,
        label=r'Scatter $x=k\pi/4$'
    )

    ax.set_title(label, fontsize=10)
    ax.set_xlabel('x')
    if ax is axes[0]:
        ax.set_ylabel('f(x)')
    ax.grid(True)
    ax.legend(loc='upper left', fontsize=9)
    ax.set_xlim(-2 * np.pi, 2 * np.pi)
    ax.set_ylim(-7, 7)
fig.suptitle('Style comparison: same plot rendered with three different matplotlib styles', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
print("Comparison summary:")
print("- 'default': plain white background, thin axes lines, default color cycle; good for simple, publication-style figures.")
print("- 'seaborn-v0_8-whitegrid': light background with subtle gridlines and slightly bolder fonts; helps read values and is good for exploratory plots.")
print("- 'ggplot': muted color palette, thicker gridlines and a softer aesthetic; pleasing for presentations and when you want a 'styled' look.")
print("\nRecommendation: For precise, publication-ready plots use 'default' (then customize fonts and ticks). For interactive exploration or slides, 'seaborn-v0_8-whitegrid' or 'ggplot' can be more readable and visually appealing.")
# Out:
# Comparison summary:
# - 'default': plain white background, thin axes lines, default color cycle; good for simple, publication-style figures.
# - 'seaborn-v0_8-whitegrid': light background with subtle gridlines and slightly bolder fonts; helps read values and is good for exploratory plots.
# - 'ggplot': muted color palette, thicker gridlines and a softer aesthetic; pleasing for presentations and when you want a 'styled' look.
#
# Recommendation: For precise, publication-ready plots use 'default' (then customize fonts and ticks). For interactive exploration or slides, 'seaborn-v0_8-whitegrid' or 'ggplot' can be more readable and visually appealing.

# %% [markdown]
# ## Submission Guidelines
#
# 1. Complete the assignment in Google Colab.
# 2. Name your notebook `week3_assignment.ipynb`.
# 3. Ensure all code cells are executed and outputs are visible.
# 4. Include comments explaining your code where necessary.
# 5. Save a copy of your completed notebook to your GitHub repository:
#    - In Google Colab, go to File > Save a copy in GitHub.
#    - Select your repository and choose a path for the file.
#    - Commit the file directly to the main branch of your repository.
# 6. Submit the following to your GitHub:
#    - The direct link to your `week3_assignment.ipynb` file on GitHub.
#    - The link to your GitHub repository.

# %% [markdown]
# ------------

# %% [markdown]
# ## Reference: Mathematical functions <a id='Mathematical-Functions'></a>
# https://numpy.org/doc/stable/reference/routines.math.html
